# %% [markdown]
# <a href="https://colab.research.google.com/github/Balram524/Computer-Vision/blob/mains/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from skimage import data, io
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# loading an image and checkings its datatype

# %%
# Skimage.data has a lot of sample images to play around with
image  = data.coins()

print(type(image))

plt.imshow(image, cmap = 'gray')
plt.axis("off")
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
# import image from the local
from google.colab import files
uploaded = files.upload()

# check for the uploaded file
import os
os.listdir()

# load the image
from PIL import Image
img = Image.open('Balram Nishad1.jpeg')
img.show()
# Out:
#      <input type="file" id="files-4268c592-4fac-4806-b101-63ed205f5b89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4268c592-4fac-4806-b101-63ed205f5b89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2

img = cv2.imread("Balram Nishad.jpeg")  # Replace with the actual filename
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()

# %%
print(image.shape)
# Out:
# (303, 384)

# %%
print(image[45,89])
# Out:
# 182

# %%
plt.imshow(image[111:176, 96: 150], cmap = 'Greens')
plt.axis("off")
plt.show()
